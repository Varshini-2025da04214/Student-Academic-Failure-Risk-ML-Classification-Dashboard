# %% [markdown]
# # Exploratory Data Analysis - Student Academic Failure Risk
# This notebook contains the exploratory analysis for Assignment 2.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load clean data
df = pd.read_csv('../data/AI_SocialMedia_Student_Health_Dataset_clean.csv')
print(df.shape)
df.head()
